# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3e5f77411b443d6ecbdbadd21fad8856

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description": weather_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | burnie
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | kearney
# Processing Record 5 of Set 1 | tezu
# Processing Record 6 of Set 1 | qaanaaq
# Processing Record 7 of Set 1 | cape town
# Processing Record 8 of Set 1 | polunochnoye
# Processing Record 9 of Set 1 | bathsheba
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | saint-philippe
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | lidorikion
# City not found. Skipping...
# Processing Record 14 of Set 1 | takoradi
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | bhatkal
# Processing Record 17 of Set 1 | tuktoyaktuk
# Processing Record 18 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 19 of Set 1 | arlit
# Processing Record 20 of Set 1 | pangnirtung
# Processing Record 21 of Set 1 | bengkulu
# Processing Record 22 of Set 1 | royan
# Processing Record 23 of Set 1 | naze
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | hermanus
# Processing Record 26 of Set 1 | beringovskiy
# Processing Record 27 of Set 1 | coffs harbour
# Processing Record 28 of Set 1 | nanortalik
# Processing Record 29 of Set 1 | chimoio
# Processing Record 30 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | dingle
# Processing Record 35 of Set 1 | cap malheureux
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | iroquois falls
# Processing Record 38 of Set 1 | narsaq
# Processing Record 39 of Set 1 | lavrentiya
# Processing Record 40 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | fort nelson
# Processing Record 43 of Set 1 | dangtu
# Processing Record 44 of Set 1 | clyde river
# Processing Record 45 of Set 1 | haines junction
# Processing Record 46 of Set 1 | bluff
# Processing Record 47 of Set 1 | semey
# Processing Record 48 of Set 1 | pandan
# Processing Record 49 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 50 of Set 1 | vestmannaeyjar
# Processing Record 1 of Set 2 | castro
# Processing Record 2 of Set 2 | atuona
# Processing Record 3 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 2 | port hedland
# Processing Record 5 of Set 2 | kysyl-syr
# Processing Record 6 of Set 2 | vao
# Processing Record 7 of Set 2 | jamestown
# Processing Record 8 of Set 2 | vaini
# Processing Record 9 of Set 2 | flinders
# Processing Record 10 of Set 2 | ballstad
# City not found. Skipping...
# Processing Record 11 of Set 2 | samarai
# Processing Record 12 of Set 2 | isangel
# Processing Record 13 of Set 2 | hilo
# Processing Record 14 of Set 2 | la rioja
# Processing Record 15 of Set 2 | hobart
# Processing Record 16 of Set 2 | mosetse
# Processing Record 17 of Set 2 | port elizabeth
# Processing Record 18 of Set 2 | tonantins
# Processing Record 19 of Set 2 | sann
# Processing Record 20 of Set 2 | jumla
# Processing Record 21 of Set 2 | londoko
# Processing Record 22 of Set 2 | tibacuy
# Processing Record 23 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 24 of Set 2 | hendrina
# Processing Record 25 of Set 2 | maniitsoq
# Processing Record 26 of Set 2 | tsiroanomandidy
# Processing Record 27 of Set 2 | malinovoye ozero
# Processing Record 28 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | upernavik
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | pangody
# Processing Record 35 of Set 2 | tuy hoa
# Processing Record 36 of Set 2 | dikson
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | goma
# Processing Record 39 of Set 2 | sioux lookout
# Processing Record 40 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 41 of Set 2 | devils lake
# Processing Record 42 of Set 2 | warmbad
# Processing Record 43 of Set 2 | zhuanghe
# Processing Record 44 of Set 2 | isabela
# Processing Record 45 of Set 2 | kamenka
# Processing Record 46 of Set 2 | margate
# Processing Record 47 of Set 2 | hatillo
# Processing Record 48 of Set 2 | manta
# Processing Record 49 of Set 2 | khatanga
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | ermoupolis
# Processing Record 2 of Set 3 | chuy
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | uvarovo
# Processing Record 5 of Set 3 | albany
# Processing Record 6 of Set 3 | kapaa
# Processing Record 7 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | ambodifototra
# City not found. Skipping...
# Processing Record 10 of Set 3 | butaritari
# Processing Record 11 of Set 3 | mao
# Processing Record 12 of Set 3 | half moon bay
# Processing Record 13 of Set 3 | barrow
# Processing Record 14 of Set 3 | ambon
# Processing Record 15 of Set 3 | valparaiso
# Processing Record 16 of Set 3 | bredasdorp
# Processing Record 17 of Set 3 | el alto
# Processing Record 18 of Set 3 | poum
# Processing Record 19 of Set 3 | cabo rojo
# Processing Record 20 of Set 3 | la ronge
# Processing Record 21 of Set 3 | nyurba
# Processing Record 22 of Set 3 | yar-sale
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | hokitika
# Processing Record 25 of Set 3 | anadyr
# Processing Record 26 of Set 3 | myitkyina
# Processing Record 27 of Set 3 | tambopata
# Processing Record 28 of Set 3 | mar del plata
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 3 | hithadhoo
# Processing Record 31 of Set 3 | maryborough
# Processing Record 32 of Set 3 | khilok
# Processing Record 33 of Set 3 | terney
# Processing Record 34 of Set 3 | blackwater
# Processing Record 35 of Set 3 | marmande
# Processing Record 36 of Set 3 | ulaangom
# Processing Record 37 of Set 3 | rawson
# Processing Record 38 of Set 3 | okandja
# City not found. Skipping...
# Processing Record 39 of Set 3 | tezpur
# Processing Record 40 of Set 3 | cherskiy
# Processing Record 41 of Set 3 | mlonggo
# Processing Record 42 of Set 3 | tabou
# Processing Record 43 of Set 3 | farrukhnagar
# Processing Record 44 of Set 3 | carahue
# Processing Record 45 of Set 3 | southbridge
# Processing Record 46 of Set 3 | beloha
# Processing Record 47 of Set 3 | touros
# Processing Record 48 of Set 3 | maldonado
# Processing Record 49 of Set 3 | nome
# Processing Record 50 of Set 3 | kahului
# Processing Record 1 of Set 4 | kavaratti
# Processing Record 2 of Set 4 | mayo
# Processing Record 3 of Set 4 | derzhavinsk
# Processing Record 4 of Set 4 | abu samrah
# Processing Record 5 of Set 4 | port blair
# Processing Record 6 of Set 4 | manhuacu
# Processing Record 7 of Set 4 | uige
# Processing Record 8 of Set 4 | mount isa
# Processing Record 9 of Set 4 | siddipet
# Processing Record 10 of Set 4 | champerico
# Processing Record 11 of Set 4 | pagman
# City not found. Skipping...
# Processing Record 12 of Set 4 | port moresby
# Processing Record 13 of Set 4 | maneadero
# Processing Record 14 of Set 4 | yamaranguila
# Processing Record 15 of Set 4 | makakilo city
# Processing Record 16 of Set 4 | behbahan
# Processing Record 17 of Set 4 | saldanha
# Processing Record 18 of Set 4 | zelenoborsk
# Processing Record 19 of Set 4 | caravelas
# Processing Record 20 of Set 4 | kalmunai
# Processing Record 21 of Set 4 | kodiak
# Processing Record 22 of Set 4 | alytus
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | rio verde de mato grosso
# Processing Record 26 of Set 4 | moron
# Processing Record 27 of Set 4 | whitehorse
# Processing Record 28 of Set 4 | richards bay
# Processing Record 29 of Set 4 | yulara
# Processing Record 30 of Set 4 | torbay
# Processing Record 31 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 4 | okakarara
# Processing Record 33 of Set 4 | kadykchan
# City not found. Skipping...
# Processing Record 34 of Set 4 | moerai
# Processing Record 35 of Set 4 | yacuiba
# Processing Record 36 of Set 4 | haibowan
# City not found. Skipping...
# Processing Record 37 of Set 4 | christchurch
# Processing Record 38 of Set 4 | jiazi
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | mana
# Processing Record 41 of Set 4 | aleksandrovka
# Processing Record 42 of Set 4 | alofi
# Processing Record 43 of Set 4 | liebling
# Processing Record 44 of Set 4 | dunedin
# Processing Record 45 of Set 4 | new norfolk
# Processing Record 46 of Set 4 | alagoinhas
# Processing Record 47 of Set 4 | luba
# Processing Record 48 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 49 of Set 4 | rio grande
# Processing Record 50 of Set 4 | meulaboh
# Processing Record 1 of Set 5 | thompson
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | mahebourg
# Processing Record 4 of Set 5 | taburi
# City not found. Skipping...
# Processing Record 5 of Set 5 | tampakan
# Processing Record 6 of Set 5 | stepnyak
# Processing Record 7 of Set 5 | lethem
# Processing Record 8 of Set 5 | geraldton
# Processing Record 9 of Set 5 | erenhot
# Processing Record 10 of Set 5 | provideniya
# Processing Record 11 of Set 5 | severo-kurilsk
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | portobelo
# Processing Record 14 of Set 5 | gat
# Processing Record 15 of Set 5 | uarini
# Processing Record 16 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 5 | pevek
# Processing Record 18 of Set 5 | hobyo
# Processing Record 19 of Set 5 | tual
# Processing Record 20 of Set 5 | sisimiut
# Processing Record 21 of Set 5 | sobolevo
# Processing Record 22 of Set 5 | sept-iles
# Processing Record 23 of Set 5 | ishigaki
# Processing Record 24 of Set 5 | yaan
# Processing Record 25 of Set 5 | halifax
# Processing Record 26 of Set 5 | laguna
# Processing Record 27 of Set 5 | simao
# Processing Record 28 of Set 5 | vila velha
# Processing Record 29 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 30 of Set 5 | farmington
# Processing Record 31 of Set 5 | pleshanovo
# Processing Record 32 of Set 5 | varhaug
# Processing Record 33 of Set 5 | barcelona
# Processing Record 34 of Set 5 | aybak
# City not found. Skipping...
# Processing Record 35 of Set 5 | kenai
# Processing Record 36 of Set 5 | paranapanema
# Processing Record 37 of Set 5 | oussouye
# Processing Record 38 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 5 | mon
# Processing Record 40 of Set 5 | ponta do sol
# Processing Record 41 of Set 5 | comodoro rivadavia
# Processing Record 42 of Set 5 | khani
# Processing Record 43 of Set 5 | panaba
# Processing Record 44 of Set 5 | iquique
# Processing Record 45 of Set 5 | georgetown
# Processing Record 46 of Set 5 | lorengau
# Processing Record 47 of Set 5 | saskylakh
# Processing Record 48 of Set 5 | taoudenni
# Processing Record 49 of Set 5 | bryan
# Processing Record 50 of Set 5 | oistins
# Processing Record 1 of Set 6 | gigmoto
# Processing Record 2 of Set 6 | kamina
# Processing Record 3 of Set 6 | lazaro cardenas
# Processing Record 4 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 6 | ancud
# Processing Record 6 of Set 6 | tarakan
# Processing Record 7 of Set 6 | horodnytsya
# Processing Record 8 of Set 6 | san pedro de macoris
# Processing Record 9 of Set 6 | roald
# Processing Record 10 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | alice springs
# Processing Record 13 of Set 6 | padilla
# Processing Record 14 of Set 6 | taywarah
# Processing Record 15 of Set 6 | matagami
# Processing Record 16 of Set 6 | nalut
# Processing Record 17 of Set 6 | pucallpa
# Processing Record 18 of Set 6 | ribeira grande
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | mahadday weyne
# City not found. Skipping...
# Processing Record 21 of Set 6 | soyo
# Processing Record 22 of Set 6 | axim
# Processing Record 23 of Set 6 | korla
# Processing Record 24 of Set 6 | ishinomaki
# Processing Record 25 of Set 6 | elbistan
# Processing Record 26 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 6 | mitsamiouli
# Processing Record 28 of Set 6 | angoche
# Processing Record 29 of Set 6 | sao joao da barra
# Processing Record 30 of Set 6 | thunder bay
# Processing Record 31 of Set 6 | dudinka
# Processing Record 32 of Set 6 | burica
# City not found. Skipping...
# Processing Record 33 of Set 6 | oak ridge
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | shimoda
# Processing Record 36 of Set 6 | sabla
# Processing Record 37 of Set 6 | sawakin
# Processing Record 38 of Set 6 | aripuana
# Processing Record 39 of Set 6 | onega
# Processing Record 40 of Set 6 | baykit
# Processing Record 41 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 6 | grand gaube
# Processing Record 43 of Set 6 | husavik
# Processing Record 44 of Set 6 | tiksi
# Processing Record 45 of Set 6 | zavitinsk
# Processing Record 46 of Set 6 | ajdabiya
# Processing Record 47 of Set 6 | san quintin
# Processing Record 48 of Set 6 | hami
# Processing Record 49 of Set 6 | laibin
# Processing Record 50 of Set 6 | ambatondrazaka
# Processing Record 1 of Set 7 | tayzhina
# Processing Record 2 of Set 7 | mukhen
# Processing Record 3 of Set 7 | livani
# Processing Record 4 of Set 7 | teahupoo
# Processing Record 5 of Set 7 | urumqi
# Processing Record 6 of Set 7 | tuatapere
# Processing Record 7 of Set 7 | kruisfontein
# Processing Record 8 of Set 7 | gornopravdinsk
# Processing Record 9 of Set 7 | kavieng
# Processing Record 10 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 7 | cabo san lucas
# Processing Record 12 of Set 7 | nenjiang
# Processing Record 13 of Set 7 | vallentuna
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | grindavik
# Processing Record 16 of Set 7 | huarmey
# Processing Record 17 of Set 7 | siyabuswa
# Processing Record 18 of Set 7 | praia da vitoria
# Processing Record 19 of Set 7 | kiruna
# Processing Record 20 of Set 7 | mount gambier
# Processing Record 21 of Set 7 | thiers
# Processing Record 22 of Set 7 | sinnamary
# Processing Record 23 of Set 7 | dwarka
# Processing Record 24 of Set 7 | banda aceh
# Processing Record 25 of Set 7 | bambanglipuro
# Processing Record 26 of Set 7 | san ramon
# Processing Record 27 of Set 7 | araouane
# Processing Record 28 of Set 7 | chokurdakh
# Processing Record 29 of Set 7 | leningradskiy
# Processing Record 30 of Set 7 | waingapu
# Processing Record 31 of Set 7 | krasnyy chikoy
# Processing Record 32 of Set 7 | coquimbo
# Processing Record 33 of Set 7 | kyren
# Processing Record 34 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 7 | mpika
# Processing Record 36 of Set 7 | nikolskoye
# Processing Record 37 of Set 7 | zheleznodorozhnyy
# Processing Record 38 of Set 7 | fortuna
# Processing Record 39 of Set 7 | houma
# Processing Record 40 of Set 7 | chengde
# Processing Record 41 of Set 7 | souris
# Processing Record 42 of Set 7 | faanui
# Processing Record 43 of Set 7 | esperance
# Processing Record 44 of Set 7 | mubi
# Processing Record 45 of Set 7 | salalah
# Processing Record 46 of Set 7 | bilma
# Processing Record 47 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 7 | santa cruz
# Processing Record 49 of Set 7 | vostok
# Processing Record 50 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 8 | bubaque
# Processing Record 2 of Set 8 | sitka
# Processing Record 3 of Set 8 | strezhevoy
# Processing Record 4 of Set 8 | hambantota
# Processing Record 5 of Set 8 | ranong
# Processing Record 6 of Set 8 | the valley
# Processing Record 7 of Set 8 | wagar
# Processing Record 8 of Set 8 | buala
# Processing Record 9 of Set 8 | nagato
# Processing Record 10 of Set 8 | gazojak
# Processing Record 11 of Set 8 | inderborskiy
# City not found. Skipping...
# Processing Record 12 of Set 8 | camacha
# Processing Record 13 of Set 8 | ostrovnoy
# Processing Record 14 of Set 8 | carsamba
# Processing Record 15 of Set 8 | naivasha
# Processing Record 16 of Set 8 | bermejo
# Processing Record 17 of Set 8 | mahina
# Processing Record 18 of Set 8 | rosarito
# Processing Record 19 of Set 8 | verkhnyaya inta
# Processing Record 20 of Set 8 | grand island
# Processing Record 21 of Set 8 | fereydunshahr
# Processing Record 22 of Set 8 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 23 of Set 8 | vagur
# Processing Record 24 of Set 8 | olafsvik
# Processing Record 25 of Set 8 | nador
# Processing Record 26 of Set 8 | maues
# Processing Record 27 of Set 8 | juifang
# City not found. Skipping...
# Processing Record 28 of Set 8 | ketchikan
# Processing Record 29 of Set 8 | chilakalurupet
# Processing Record 30 of Set 8 | harbour breton
# Processing Record 31 of Set 8 | gamba
# Processing Record 32 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 8 | nhulunbuy
# Processing Record 34 of Set 8 | dubbo
# Processing Record 35 of Set 8 | vila
# Processing Record 36 of Set 8 | sao paulo de olivenca
# Processing Record 37 of Set 8 | namie
# Processing Record 38 of Set 8 | saint george
# Processing Record 39 of Set 8 | wangou
# Processing Record 40 of Set 8 | norman wells
# Processing Record 41 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 42 of Set 8 | bossangoa
# Processing Record 43 of Set 8 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 44 of Set 8 | postojna
# Processing Record 45 of Set 8 | klaksvik
# Processing Record 46 of Set 8 | tahta
# Processing Record 47 of Set 8 | monthey
# Processing Record 48 of Set 8 | oneonta
# Processing Record 49 of Set 8 | qaqortoq
# Processing Record 50 of Set 8 | acari
# Processing Record 1 of Set 9 | buraydah
# Processing Record 2 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 9 | yumen
# Processing Record 4 of Set 9 | angelholm
# City not found. Skipping...
# Processing Record 5 of Set 9 | westport
# Processing Record 6 of Set 9 | paita
# Processing Record 7 of Set 9 | aksarka
# Processing Record 8 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 9 | itaueira
# Processing Record 10 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 11 of Set 9 | tiznit
# Processing Record 12 of Set 9 | lovozero
# Processing Record 13 of Set 9 | cidreira
# Processing Record 14 of Set 9 | tilichiki
# Processing Record 15 of Set 9 | sinegorye
# Processing Record 16 of Set 9 | dundee
# Processing Record 17 of Set 9 | sombrio
# Processing Record 18 of Set 9 | moita
# Processing Record 19 of Set 9 | antalaha
# Processing Record 20 of Set 9 | qingdao
# Processing Record 21 of Set 9 | plettenberg bay
# Processing Record 22 of Set 9 | miraflores
# Processing Record 23 of Set 9 | killybegs
# Processing Record 24 of Set 9 | angra
# City not found. Skipping...
# Processing Record 25 of Set 9 | aire-sur-la-lys
# Processing Record 26 of Set 9 | afanasyevo
# City not found. Skipping...
# Processing Record 27 of Set 9 | stawell
# Processing Record 28 of Set 9 | goba
# Processing Record 29 of Set 9 | khorixas
# Processing Record 30 of Set 9 | nouadhibou
# Processing Record 31 of Set 9 | santa fe
# Processing Record 32 of Set 9 | pedasi
# Processing Record 33 of Set 9 | djibo
# Processing Record 34 of Set 9 | goderich
# Processing Record 35 of Set 9 | ati
# Processing Record 36 of Set 9 | san michele al tagliamento
# Processing Record 37 of Set 9 | lavumisa
# Processing Record 38 of Set 9 | komsomolskiy
# Processing Record 39 of Set 9 | nemuro
# Processing Record 40 of Set 9 | kommunisticheskiy
# Processing Record 41 of Set 9 | la grande
# Processing Record 42 of Set 9 | shubarshi
# Processing Record 43 of Set 9 | baghdad
# Processing Record 44 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 45 of Set 9 | okhotsk
# Processing Record 46 of Set 9 | umm lajj
# Processing Record 47 of Set 9 | montepuez
# Processing Record 48 of Set 9 | arawa
# Processing Record 49 of Set 9 | qom
# Processing Record 50 of Set 9 | shenjiamen
# Processing Record 1 of Set 10 | chupei
# City not found. Skipping...
# Processing Record 2 of Set 10 | ellensburg
# Processing Record 3 of Set 10 | katherine
# Processing Record 4 of Set 10 | fernie
# Processing Record 5 of Set 10 | syamzha
# Processing Record 6 of Set 10 | anori
# Processing Record 7 of Set 10 | mogadishu
# Processing Record 8 of Set 10 | souillac
# Processing Record 9 of Set 10 | palmas
# Processing Record 10 of Set 10 | bad kreuznach
# Processing Record 11 of Set 10 | rapid valley
# Processing Record 12 of Set 10 | crystal beach
# Processing Record 13 of Set 10 | gravdal
# Processing Record 14 of Set 10 | najran
# Processing Record 15 of Set 10 | mapiripan
# Processing Record 16 of Set 10 | kharan
# Processing Record 17 of Set 10 | atbasar
# Processing Record 18 of Set 10 | padang
# Processing Record 19 of Set 10 | eydhafushi
# Processing Record 20 of Set 10 | dera bugti
# Processing Record 21 of Set 10 | necochea
# Processing Record 22 of Set 10 | muros
# Processing Record 23 of Set 10 | vardo
# Processing Record 24 of Set 10 | mbuji-mayi
# Processing Record 25 of Set 10 | lafia
# Processing Record 26 of Set 10 | znamenka
# Processing Record 27 of Set 10 | new plymouth
# Processing Record 28 of Set 10 | belaya gora
# Processing Record 29 of Set 10 | sao filipe
# Processing Record 30 of Set 10 | guerrero negro
# Processing Record 31 of Set 10 | portland
# Processing Record 32 of Set 10 | daloa
# Processing Record 33 of Set 10 | manzanillo
# Processing Record 34 of Set 10 | portsmouth
# Processing Record 35 of Set 10 | turukhansk
# Processing Record 36 of Set 10 | vercelli
# Processing Record 37 of Set 10 | talnakh
# Processing Record 38 of Set 10 | lashio
# Processing Record 39 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 40 of Set 10 | catuday
# Processing Record 41 of Set 10 | moranbah
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | pangkalanbuun
# Processing Record 44 of Set 10 | trelew
# Processing Record 45 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 46 of Set 10 | los llanos de aridane
# Processing Record 47 of Set 10 | pareora
# Processing Record 48 of Set 10 | baculin
# Processing Record 49 of Set 10 | longyearbyen
# Processing Record 50 of Set 10 | saint anthony
# Processing Record 1 of Set 11 | presidente medici
# Processing Record 2 of Set 11 | eureka
# Processing Record 3 of Set 11 | kallaste
# Processing Record 4 of Set 11 | henties bay
# Processing Record 5 of Set 11 | fairbanks
# Processing Record 6 of Set 11 | paamiut
# Processing Record 7 of Set 11 | potsdam
# Processing Record 8 of Set 11 | kattivakkam
# Processing Record 9 of Set 11 | zyryanka
# Processing Record 10 of Set 11 | pachino
# Processing Record 11 of Set 11 | itoman
# Processing Record 12 of Set 11 | port augusta
# Processing Record 13 of Set 11 | salinas
# Processing Record 14 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 11 | mkuranga
# Processing Record 16 of Set 11 | amapa
# Processing Record 17 of Set 11 | nabire
# Processing Record 18 of Set 11 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 11 | lesnoy
# Processing Record 20 of Set 11 | nosy varika
# Processing Record 21 of Set 11 | xinzhou
# Processing Record 22 of Set 11 | labuhan
# Processing Record 23 of Set 11 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 24 of Set 11 | sagana
# Processing Record 25 of Set 11 | mandera
# Processing Record 26 of Set 11 | shupiyan
# Processing Record 27 of Set 11 | bloomington
# Processing Record 28 of Set 11 | umm kaddadah
# Processing Record 29 of Set 11 | abu zabad
# Processing Record 30 of Set 11 | tautira
# Processing Record 31 of Set 11 | deniliquin
# Processing Record 32 of Set 11 | ossora
# Processing Record 33 of Set 11 | sinazongwe
# Processing Record 34 of Set 11 | puerto quijarro
# Processing Record 35 of Set 11 | srednekolymsk
# Processing Record 36 of Set 11 | san vicente
# Processing Record 37 of Set 11 | hamilton
# Processing Record 38 of Set 11 | hammerfest
# Processing Record 39 of Set 11 | ahipara
# Processing Record 40 of Set 11 | charters towers
# Processing Record 41 of Set 11 | luderitz
# Processing Record 42 of Set 11 | tasiilaq
# Processing Record 43 of Set 11 | chapada dos guimaraes
# Processing Record 44 of Set 11 | lagoa
# Processing Record 45 of Set 11 | bayji
# Processing Record 46 of Set 11 | coahuayana
# Processing Record 47 of Set 11 | kimbe
# Processing Record 48 of Set 11 | contamana
# Processing Record 49 of Set 11 | brae
# Processing Record 50 of Set 11 | saint-joseph
# Processing Record 1 of Set 12 | abha
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | oktyabrskiy
# Processing Record 4 of Set 12 | hazorasp
# Processing Record 5 of Set 12 | olinda
# Processing Record 6 of Set 12 | aberdeen
# Processing Record 7 of Set 12 | hoquiam
# Processing Record 8 of Set 12 | norsup
# Processing Record 9 of Set 12 | victor harbor
# Processing Record 10 of Set 12 | pirgos
# Processing Record 11 of Set 12 | glomfjord
# Processing Record 12 of Set 12 | nha trang
# Processing Record 13 of Set 12 | synya
# Processing Record 14 of Set 12 | caraballeda
# Processing Record 15 of Set 12 | ust-tsilma
# Processing Record 16 of Set 12 | pisco
# Processing Record 17 of Set 12 | opuwo
# Processing Record 18 of Set 12 | sunrise manor
# Processing Record 19 of Set 12 | zverinogolovskoye
# Processing Record 20 of Set 12 | ninghai
# Processing Record 21 of Set 12 | pointe michel
# Processing Record 22 of Set 12 | mitu
# Processing Record 23 of Set 12 | doha
# Processing Record 24 of Set 12 | tateyama
# Processing Record 25 of Set 12 | talas
# Processing Record 26 of Set 12 | birin
# Processing Record 27 of Set 12 | katima mulilo
# Processing Record 28 of Set 12 | alyangula
# Processing Record 29 of Set 12 | holstebro
# Processing Record 30 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | aklavik
# Processing Record 32 of Set 12 | zile
# Processing Record 33 of Set 12 | salinopolis
# Processing Record 34 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 35 of Set 12 | kollam
# Processing Record 36 of Set 12 | pishin
# Processing Record 37 of Set 12 | ashti
# Processing Record 38 of Set 12 | kalyazin
# Processing Record 39 of Set 12 | coruripe
# Processing Record 40 of Set 12 | santa isabel do rio negro
# Processing Record 41 of Set 12 | novyy urengoy
# Processing Record 42 of Set 12 | turbat
# Processing Record 43 of Set 12 | tiarei
# Processing Record 44 of Set 12 | mananjary
# Processing Record 45 of Set 12 | riyadh
# Processing Record 46 of Set 12 | yarmouth
# Processing Record 47 of Set 12 | faya
# Processing Record 48 of Set 12 | vaitape
# Processing Record 49 of Set 12 | hofn
# Processing Record 50 of Set 12 | chiredzi
# Processing Record 1 of Set 13 | yatou
# Processing Record 2 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 4 of Set 13 | jutai
# Processing Record 5 of Set 13 | kawalu
# Processing Record 6 of Set 13 | muhos
# Processing Record 7 of Set 13 | ha giang
# Processing Record 8 of Set 13 | chalakudi
# Processing Record 9 of Set 13 | constantine
# Processing Record 10 of Set 13 | apatity
# Processing Record 11 of Set 13 | panama city
# Processing Record 12 of Set 13 | qui nhon
# Processing Record 13 of Set 13 | birjand
# Processing Record 14 of Set 13 | ouesso
# Processing Record 15 of Set 13 | sorland
# Processing Record 16 of Set 13 | ucluelet
# Processing Record 17 of Set 13 | mahajanga
# Processing Record 18 of Set 13 | sterling
# Processing Record 19 of Set 13 | chongwe
# Processing Record 20 of Set 13 | skalistyy
# City not found. Skipping...
# Processing Record 21 of Set 13 | giyon
# Processing Record 22 of Set 13 | mahuva
# Processing Record 23 of Set 13 | waipawa
# Processing Record 24 of Set 13 | kumeny
# Processing Record 25 of Set 13 | pampierstad
# Processing Record 26 of Set 13 | talaya
# Processing Record 27 of Set 13 | yinchuan
# Processing Record 28 of Set 13 | port-cartier
# Processing Record 29 of Set 13 | cervo
# Processing Record 30 of Set 13 | vestby
# Processing Record 31 of Set 13 | kunzelsau
# Processing Record 32 of Set 13 | cayenne
# Processing Record 33 of Set 13 | auki
# Processing Record 34 of Set 13 | dourbali
# Processing Record 35 of Set 13 | claye-souilly
# Processing Record 36 of Set 13 | bayir
# Processing Record 37 of Set 13 | askino
# Processing Record 38 of Set 13 | honiara
# Processing Record 39 of Set 13 | yamada
# Processing Record 40 of Set 13 | niteroi
# Processing Record 41 of Set 13 | namibe
# Processing Record 42 of Set 13 | te anau
# Processing Record 43 of Set 13 | kutum
# Processing Record 44 of Set 13 | marystown
# Processing Record 45 of Set 13 | mezen
# Processing Record 46 of Set 13 | barabai
# Processing Record 47 of Set 13 | lata
# Processing Record 48 of Set 13 | hoopstad
# Processing Record 49 of Set 13 | harper
# Processing Record 50 of Set 13 | uvira
# Processing Record 1 of Set 14 | lokosovo
# Processing Record 2 of Set 14 | asosa
# Processing Record 3 of Set 14 | bantry
# Processing Record 4 of Set 14 | presidencia roque saenz pena
# Processing Record 5 of Set 14 | coihaique
# Processing Record 6 of Set 14 | loiza
# Processing Record 7 of Set 14 | tevaitoa
# Processing Record 8 of Set 14 | goldsboro
# Processing Record 9 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 10 of Set 14 | mehamn
# Processing Record 11 of Set 14 | kashihara
# Processing Record 12 of Set 14 | sidi ali
# Processing Record 13 of Set 14 | san patricio
# Processing Record 14 of Set 14 | abonnema
# Processing Record 15 of Set 14 | krasnyy luch
# Processing Record 16 of Set 14 | andra
# Processing Record 17 of Set 14 | parelhas
# Processing Record 18 of Set 14 | martin
# Processing Record 19 of Set 14 | de-kastri
# Processing Record 20 of Set 14 | arona
# Processing Record 21 of Set 14 | perivolion
# Processing Record 22 of Set 14 | ballarat
# Processing Record 23 of Set 14 | ternate
# Processing Record 24 of Set 14 | coxim
# Processing Record 25 of Set 14 | atar
# Processing Record 26 of Set 14 | markala
# Processing Record 27 of Set 14 | pizarro
# Processing Record 28 of Set 14 | san antonio
# Processing Record 29 of Set 14 | shubarkuduk
# Processing Record 30 of Set 14 | neiafu
# Processing Record 31 of Set 14 | dhidhdhoo
# Processing Record 32 of Set 14 | blagoyevo
# Processing Record 33 of Set 14 | gushikawa
# Processing Record 34 of Set 14 | jackson
# Processing Record 35 of Set 14 | yunyang
# Processing Record 36 of Set 14 | hinatuan
# Processing Record 37 of Set 14 | gorontalo
# Processing Record 38 of Set 14 | andarab
# City not found. Skipping...
# Processing Record 39 of Set 14 | lasa
# Processing Record 40 of Set 14 | avera
# Processing Record 41 of Set 14 | verkhnevilyuysk
# Processing Record 42 of Set 14 | leticia
# Processing Record 43 of Set 14 | sechura
# Processing Record 44 of Set 14 | calvinia
# Processing Record 45 of Set 14 | imeni poliny osipenko
# Processing Record 46 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 14 | port-gentil
# Processing Record 48 of Set 14 | omsukchan
# Processing Record 49 of Set 14 | kiryas joel
# Processing Record 50 of Set 14 | salard
# Processing Record 1 of Set 15 | boguchany
# Processing Record 2 of Set 15 | arkadelphia
# Processing Record 3 of Set 15 | teya
# Processing Record 4 of Set 15 | kailua
# Processing Record 5 of Set 15 | douentza
# Processing Record 6 of Set 15 | erechim
# Processing Record 7 of Set 15 | gurlan
# Processing Record 8 of Set 15 | america dourada
# Processing Record 9 of Set 15 | kitimat
# Processing Record 10 of Set 15 | nanakuli
# Processing Record 11 of Set 15 | vysokogornyy
# Processing Record 12 of Set 15 | yuanping
# Processing Record 13 of Set 15 | sharanga
# Processing Record 14 of Set 15 | monte patria
# Processing Record 15 of Set 15 | nambour
# Processing Record 16 of Set 15 | ola
# Processing Record 17 of Set 15 | banavar
# Processing Record 18 of Set 15 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 19 of Set 15 | hervey bay
# Processing Record 20 of Set 15 | matadi
# Processing Record 21 of Set 15 | zhovtneve
# Processing Record 22 of Set 15 | stornoway
# Processing Record 23 of Set 15 | tuggurt
# City not found. Skipping...
# Processing Record 24 of Set 15 | povolzhskiy
# Processing Record 25 of Set 15 | nobres
# Processing Record 26 of Set 15 | artyk
# City not found. Skipping...
# Processing Record 27 of Set 15 | mingguang
# Processing Record 28 of Set 15 | morro bay
# Processing Record 29 of Set 15 | ballina
# Processing Record 30 of Set 15 | zhigansk
# Processing Record 31 of Set 15 | yavaros
# Processing Record 32 of Set 15 | cururupu
# Processing Record 33 of Set 15 | chifeng
# Processing Record 34 of Set 15 | sangar
# Processing Record 35 of Set 15 | koumac
# Processing Record 36 of Set 15 | toro
# Processing Record 37 of Set 15 | balclutha
# Processing Record 38 of Set 15 | fort saint john
# City not found. Skipping...
# Processing Record 39 of Set 15 | boende
# Processing Record 40 of Set 15 | peachland
# Processing Record 41 of Set 15 | macon
# Processing Record 42 of Set 15 | erdenet
# Processing Record 43 of Set 15 | kholm
# Processing Record 44 of Set 15 | price
# Processing Record 45 of Set 15 | orlik
# Processing Record 46 of Set 15 | santa cruz cabralia
# Processing Record 47 of Set 15 | sarab
# Processing Record 48 of Set 15 | safaqis
# City not found. Skipping...
# Processing Record 49 of Set 15 | gazli
# Processing Record 50 of Set 15 | roma
# Processing Record 1 of Set 16 | balakhninskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 686

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Burnie -41.0667  145.9167     64.00        67          52
# 1  Punta Arenas -53.1500  -70.9167     39.20        87          75
# 2          Lebu -37.6167  -73.6500     54.30        91          93
# 3       Kearney  40.6995  -99.0815     55.40        87           1
# 4          Tezu  27.9167   96.1667     94.39        19          65
# 5       Qaanaaq  77.4840  -69.3632     22.44        88         100
# 6     Cape Town -33.9258   18.4232     57.99        94          20
# 7  Polunochnoye  60.8697   60.4153     38.89        76          96
# 8     Bathsheba  13.2167  -59.5167     78.80        65          40
# 9     Busselton -33.6500  115.3333     72.00        80         100
#
#    Wind Speed Country Weather Description                 Date
# 0        5.99      AU       broken clouds  2021-04-29 03:28:12
# 1       16.11      CL       broken clouds  2021-04-29 03:28:13
# 2        4.47      CL     overcast clouds  2021-04-29 03:27:16
# 3        4.61      US           clear sky  2021-04-29 03:28:13
# 4        4.76      IN       broken clouds  2021-04-29 03:28:14
# 5        4.81      GL     overcast clouds  2021-04-29 03:28:14
# 6        4.61      ZA          few clouds  2021-04-29 03:24:43
# 7        7.36      RU     overcast clouds  2021-04-29 03:28:15
# 8       19.57      BB    scattered clouds  2021-04-29 03:28:15
# 9        5.99      AU       moderate rain  2021-04-29 03:27:10

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Burnie      AU -41.0667  145.9167     64.00        67          52
# 1  Punta Arenas      CL -53.1500  -70.9167     39.20        87          75
# 2          Lebu      CL -37.6167  -73.6500     54.30        91          93
# 3       Kearney      US  40.6995  -99.0815     55.40        87           1
# 4          Tezu      IN  27.9167   96.1667     94.39        19          65
# 5       Qaanaaq      GL  77.4840  -69.3632     22.44        88         100
# 6     Cape Town      ZA -33.9258   18.4232     57.99        94          20
# 7  Polunochnoye      RU  60.8697   60.4153     38.89        76          96
# 8     Bathsheba      BB  13.2167  -59.5167     78.80        65          40
# 9     Busselton      AU -33.6500  115.3333     72.00        80         100
#
#    Wind Speed Weather Description
# 0        5.99       broken clouds
# 1       16.11       broken clouds
# 2        4.47     overcast clouds
# 3        4.61           clear sky
# 4        4.76       broken clouds
# 5        4.81     overcast clouds
# 6        4.61          few clouds
# 7        7.36     overcast clouds
# 8       19.57    scattered clouds
# 9        5.99       moderate rain

# %%
# Create the output file (CSV).
output_data_file = "../Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
